# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np

# %%
SM = [1840.29, 648.79,  23.70]
EEV = [1845.04, 657.076, 25.76]
DELTA = [(j - i)*100/i  for (i,j) in zip (SM, EEV)]
legend = ['SM', 'EEV']
xlabels = [100, 150, 200]
xlabel = '$C$'
ylabel = 'Obj. function'

# %%
x = np.arange(len(xlabels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, SM, width, label=legend[0])
rects2 = ax.bar(x + width/2, EEV, width, label=legend[1])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylabel)
ax.set_xlabel(xlabel)
#ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


#autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
x = np.arange(len(xlabels))  # the label locations
def millions(x, pos):
    return str(x) + '%'


formatter = FuncFormatter(millions)

fig, ax = plt.subplots()
ax.yaxis.set_major_formatter(formatter)
plt.bar(x, DELTA)
plt.xticks(x,xlabels)
ax.set_xlabel(xlabel)
ax.set_title('gap of EEV solution over Stochastic solution')
#plt.show()
plt.savefig('I2S1Cap.png')
